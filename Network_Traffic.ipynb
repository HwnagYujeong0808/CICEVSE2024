# %%
import pandas as pd
df = pd.read_csv('CICEVSE2024.csv')
# Out:
# /tmp/ipykernel_2159933/99778511.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /tmp/ipykernel_2159933/99778511.py:2: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('CICEVSE2024.csv')

# %%
df.head()
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 1   1              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 2   2              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 3   3              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 4   4              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       256  ...
# 1  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       993  ...
# 2  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       139  ...
# 3  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       143  ...
# 4  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       135  ...
#
#    application_name  application_category_name  application_is_guessed  \
# 0           Unknown                Unspecified                       0
# 1             IMAPS                      Email                       1
# 2           NetBIOS                     System                       1
# 3              IMAP                      Email                       1
# 4               RPC                        RPC                       1
#
#    application_confidence  requested_server_name  client_fingerprint  \
# 0                       0                    NaN                 NaN
# 1                       1                    NaN                 NaN
# 2                       1                    NaN                 NaN
# 3                       1                    NaN                 NaN
# 4                       1                    NaN                 NaN
#
#    server_fingerprint  user_agent  content_type                 label_mul
# 0                 NaN         NaN           NaN  charging Aggressive scan
# 1                 NaN         NaN           NaN  charging Aggressive scan
# 2                 NaN         NaN           NaN  charging Aggressive scan
# 3                 NaN         NaN           NaN  charging Aggressive scan
# 4                 NaN         NaN           NaN  charging Aggressive scan
#
# [5 rows x 87 columns]

# %%
print("Descriptive Statistics:")
print(df.describe())

# Data types and missing values
print("\nData Types and Missing Values:")
print(df.info())
print("\nMissing Values Count:")
print(df.isnull().sum())
# Out:
# Descriptive Statistics:
#                  id  expiration_id      src_port      dst_port      protocol  \
# count  2.744700e+06   2.744700e+06  2.744700e+06  2.744700e+06  2.744700e+06
# mean   5.374561e+04   2.477502e-05  4.320332e+04  5.828036e+03  6.134726e+00
# std    4.915507e+04   4.977390e-03  1.565881e+04  1.197252e+04  1.365722e+00
# min    0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    1.763075e+04   0.000000e+00  3.560700e+04  8.000000e+01  6.000000e+00
# 50%    4.017200e+04   0.000000e+00  4.551900e+04  1.091000e+03  6.000000e+00
# 75%    6.734400e+04   0.000000e+00  5.516000e+04  5.903000e+03  6.000000e+00
# max    2.280000e+05   1.000000e+00  6.553500e+04  6.553500e+04  2.460000e+02
#
#          ip_version    vlan_id     tunnel_id  bidirectional_first_seen_ms  \
# count  2.744700e+06  2744700.0  2.744700e+06                 2.744700e+06
# mean   4.000039e+00        0.0  1.093016e-06                 1.703149e+12
# std    8.788533e-03        0.0  1.810814e-03                 6.687425e+07
# min    4.000000e+00        0.0  0.000000e+00                 1.702999e+12
# 25%    4.000000e+00        0.0  0.000000e+00                 1.703095e+12
# 50%    4.000000e+00        0.0  0.000000e+00                 1.703186e+12
# 75%    4.000000e+00        0.0  0.000000e+00                 1.703189e+12
# max    6.000000e+00        0.0  3.000000e+00                 1.704401e+12
#
#        bidirectional_last_seen_ms  ...  dst2src_syn_packets  \
# count                2.744700e+06  ...         2.744700e+06
# mean                 1.703149e+12  ...         1.626014e-01
# std                  6.689286e+07  ...         8.247693e-01
# min                  1.702999e+12  ...         0.000000e+00
# 25%                  1.703096e+12  ...         0.000000e+00
# 50%                  1.703186e+12  ...         0.000000e+00
# 75%                  1.703189e+12  ...         0.000000e+00
# max                  1.704402e+12  ...         1.600000e+01
#
#        dst2src_cwr_packets  dst2src_ece_packets  dst2src_urg_packets  \
# count            2744700.0         2.744700e+06            2744700.0
# mean                   0.0         1.380843e-04                  0.0
# std                    0.0         2.054871e-02                  0.0
# min                    0.0         0.000000e+00                  0.0
# 25%                    0.0         0.000000e+00                  0.0
# 50%                    0.0         0.000000e+00                  0.0
# 75%                    0.0         0.000000e+00                  0.0
# max                    0.0         5.000000e+00                  0.0
#
#        dst2src_ack_packets  dst2src_psh_packets  dst2src_rst_packets  \
# count         2.744700e+06         2.744700e+06         2.744700e+06
# mean          8.509003e-01         5.471563e-02         8.896612e-01
# std           1.728915e+01         1.688503e+01         1.274879e+00
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 25%           0.000000e+00         0.000000e+00         0.000000e+00
# 50%           1.000000e+00         0.000000e+00         1.000000e+00
# 75%           1.000000e+00         0.000000e+00         1.000000e+00
# max           6.905000e+03         6.767000e+03         1.900000e+01
#
#        dst2src_fin_packets  application_is_guessed  application_confidence
# count         2.744700e+06            2.744700e+06            2.744700e+06
# mean          7.079098e-04            3.984964e-01            4.745484e-01
# std           3.182334e-02            4.895887e-01            7.934813e-01
# min           0.000000e+00            0.000000e+00            0.000000e+00
# 25%           0.000000e+00            0.000000e+00            0.000000e+00
# 50%           0.000000e+00            0.000000e+00            0.000000e+00
# 75%           0.000000e+00            1.000000e+00            1.000000e+00
# max           7.000000e+00            1.000000e+00            6.000000e+00
#
# [8 rows x 73 columns]
#
# Data Types and Missing Values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744700 entries, 0 to 2744699
# Data columns (total 87 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   expiration_id                 int64
#  2   src_ip                        object
#  3   src_mac                       object
#  4   src_oui                       object
#  5   src_port                      int64
#  6   dst_ip                        object
#  7   dst_mac                       object
#  8   dst_oui                       object
#  9   dst_port                      int64
#  10  protocol                      int64
#  11  ip_version                    int64
#  12  vlan_id                       int64
#  13  tunnel_id                     int64
#  14  bidirectional_first_seen_ms   int64
#  15  bidirectional_last_seen_ms    int64
#  16  bidirectional_duration_ms     int64
#  17  bidirectional_packets         int64
#  18  bidirectional_bytes           int64
#  19  src2dst_first_seen_ms         int64
#  20  src2dst_last_seen_ms          int64
#  21  src2dst_duration_ms           int64
#  22  src2dst_packets               int64
#  23  src2dst_bytes                 int64
#  24  dst2src_first_seen_ms         int64
#  25  dst2src_last_seen_ms          int64
#  26  dst2src_duration_ms           int64
#  27  dst2src_packets               int64
#  28  dst2src_bytes                 int64
#  29  bidirectional_min_ps          int64
#  30  bidirectional_mean_ps         float64
#  31  bidirectional_stddev_ps       float64
#  32  bidirectional_max_ps          int64
#  33  src2dst_min_ps                int64
#  34  src2dst_mean_ps               float64
#  35  src2dst_stddev_ps             float64
#  36  src2dst_max_ps                int64
#  37  dst2src_min_ps                int64
#  38  dst2src_mean_ps               float64
#  39  dst2src_stddev_ps             float64
#  40  dst2src_max_ps                int64
#  41  bidirectional_min_piat_ms     int64
#  42  bidirectional_mean_piat_ms    float64
#  43  bidirectional_stddev_piat_ms  float64
#  44  bidirectional_max_piat_ms     int64
#  45  src2dst_min_piat_ms           int64
#  46  src2dst_mean_piat_ms          float64
#  47  src2dst_stddev_piat_ms        float64
#  48  src2dst_max_piat_ms           int64
#  49  dst2src_min_piat_ms           int64
#  50  dst2src_mean_piat_ms          float64
#  51  dst2src_stddev_piat_ms        float64
#  52  dst2src_max_piat_ms           int64
#  53  bidirectional_syn_packets     int64
#  54  bidirectional_cwr_packets     int64
#  55  bidirectional_ece_packets     int64
#  56  bidirectional_urg_packets     int64
#  57  bidirectional_ack_packets     int64
#  58  bidirectional_psh_packets     int64
#  59  bidirectional_rst_packets     int64
#  60  bidirectional_fin_packets     int64
#  61  src2dst_syn_packets           int64
#  62  src2dst_cwr_packets           int64
#  63  src2dst_ece_packets           int64
#  64  src2dst_urg_packets           int64
#  65  src2dst_ack_packets           int64
#  66  src2dst_psh_packets           int64
#  67  src2dst_rst_packets           int64
#  68  src2dst_fin_packets           int64
#  69  dst2src_syn_packets           int64
#  70  dst2src_cwr_packets           int64
#  71  dst2src_ece_packets           int64
#  72  dst2src_urg_packets           int64
#  73  dst2src_ack_packets           int64
#  74  dst2src_psh_packets           int64
#  75  dst2src_rst_packets           int64
#  76  dst2src_fin_packets           int64
#  77  application_name              object
#  78  application_category_name     object
#  79  application_is_guessed        int64
#  80  application_confidence        int64
#  81  requested_server_name         object
#  82  client_fingerprint            object
#  83  server_fingerprint            object
#  84  user_agent                    object
#  85  content_type                  object
#  86  label_mul                     object
# dtypes: float64(12), int64(61), object(14)
# memory usage: 1.8+ GB
# None
#
# Missing Values Count:
# id                          0
# expiration_id               0
# src_ip                      0
# src_mac                     0
# src_oui                     0
#                        ...
# client_fingerprint    2744102
# server_fingerprint    2744162
# user_agent            2744167
# content_type          2744559
# label_mul                   0
# Length: 87, dtype: int64

# %%
# Print columns with missing values
missing_columns = df.columns[df.isnull().sum() > 0]
print("Columns with missing values:", missing_columns.tolist())
# Out:
# Columns with missing values: ['requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type']

# %%
df_ = df.copy()
df_.drop(columns = ['requested_server_name', 'client_fingerprint', 'server_fingerprint', 'user_agent', 'content_type'], inplace = True)
df_.head()
# Out:
#    id  expiration_id          src_ip            src_mac   src_oui  src_port  \
# 0   0              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 1   1              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 2   2              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 3   3              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
# 4   4              0  192.168.137.85  a8:6b:ad:1f:9b:e5  a8:6b:ad     42750
#
#             dst_ip            dst_mac   dst_oui  dst_port  ...  \
# 0  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       256  ...
# 1  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       993  ...
# 2  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       139  ...
# 3  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       143  ...
# 4  192.168.137.226  0c:8b:95:09:c6:08  0c:8b:95       135  ...
#
#    dst2src_urg_packets  dst2src_ack_packets  dst2src_psh_packets  \
# 0                    0                    1                    0
# 1                    0                    1                    0
# 2                    0                    1                    0
# 3                    0                    1                    0
# 4                    0                    1                    0
#
#    dst2src_rst_packets  dst2src_fin_packets  application_name  \
# 0                    1                    0           Unknown
# 1                    1                    0             IMAPS
# 2                    1                    0           NetBIOS
# 3                    1                    0              IMAP
# 4                    1                    0               RPC
#
#    application_category_name  application_is_guessed  application_confidence  \
# 0                Unspecified                       0                       0
# 1                      Email                       1                       1
# 2                     System                       1                       1
# 3                      Email                       1                       1
# 4                        RPC                       1                       1
#
#                   label_mul
# 0  charging Aggressive scan
# 1  charging Aggressive scan
# 2  charging Aggressive scan
# 3  charging Aggressive scan
# 4  charging Aggressive scan
#
# [5 rows x 82 columns]

# %%
df_ = df_.dropna()
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744700 entries, 0 to 2744699
# Data columns (total 82 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id                            int64
#  1   expiration_id                 int64
#  2   src_ip                        object
#  3   src_mac                       object
#  4   src_oui                       object
#  5   src_port                      int64
#  6   dst_ip                        object
#  7   dst_mac                       object
#  8   dst_oui                       object
#  9   dst_port                      int64
#  10  protocol                      int64
#  11  ip_version                    int64
#  12  vlan_id                       int64
#  13  tunnel_id                     int64
#  14  bidirectional_first_seen_ms   int64
#  15  bidirectional_last_seen_ms    int64
#  16  bidirectional_duration_ms     int64
#  17  bidirectional_packets         int64
#  18  bidirectional_bytes           int64
#  19  src2dst_first_seen_ms         int64
#  20  src2dst_last_seen_ms          int64
#  21  src2dst_duration_ms           int64
#  22  src2dst_packets               int64
#  23  src2dst_bytes                 int64
#  24  dst2src_first_seen_ms         int64
#  25  dst2src_last_seen_ms          int64
#  26  dst2src_duration_ms           int64
#  27  dst2src_packets               int64
#  28  dst2src_bytes                 int64
#  29  bidirectional_min_ps          int64
#  30  bidirectional_mean_ps         float64
#  31  bidirectional_stddev_ps       float64
#  32  bidirectional_max_ps          int64
#  33  src2dst_min_ps                int64
#  34  src2dst_mean_ps               float64
#  35  src2dst_stddev_ps             float64
#  36  src2dst_max_ps                int64
#  37  dst2src_min_ps                int64
#  38  dst2src_mean_ps               float64
#  39  dst2src_stddev_ps             float64
#  40  dst2src_max_ps                int64
#  41  bidirectional_min_piat_ms     int64
#  42  bidirectional_mean_piat_ms    float64
#  43  bidirectional_stddev_piat_ms  float64
#  44  bidirectional_max_piat_ms     int64
#  45  src2dst_min_piat_ms           int64
#  46  src2dst_mean_piat_ms          float64
#  47  src2dst_stddev_piat_ms        float64
#  48  src2dst_max_piat_ms           int64
#  49  dst2src_min_piat_ms           int64
#  50  dst2src_mean_piat_ms          float64
#  51  dst2src_stddev_piat_ms        float64
#  52  dst2src_max_piat_ms           int64
#  53  bidirectional_syn_packets     int64
#  54  bidirectional_cwr_packets     int64
#  55  bidirectional_ece_packets     int64
#  56  bidirectional_urg_packets     int64
#  57  bidirectional_ack_packets     int64
#  58  bidirectional_psh_packets     int64
#  59  bidirectional_rst_packets     int64
#  60  bidirectional_fin_packets     int64
#  61  src2dst_syn_packets           int64
#  62  src2dst_cwr_packets           int64
#  63  src2dst_ece_packets           int64
#  64  src2dst_urg_packets           int64
#  65  src2dst_ack_packets           int64
#  66  src2dst_psh_packets           int64
#  67  src2dst_rst_packets           int64
#  68  src2dst_fin_packets           int64
#  69  dst2src_syn_packets           int64
#  70  dst2src_cwr_packets           int64
#  71  dst2src_ece_packets           int64
#  72  dst2src_urg_packets           int64
#  73  dst2src_ack_packets           int64
#  74  dst2src_psh_packets           int64
#  75  dst2src_rst_packets           int64
#  76  dst2src_fin_packets           int64
#  77  application_name              object
#  78  application_category_name     object
#  79  application_is_guessed        int64
#  80  application_confidence        int64
#  81  label_mul                     object
# dtypes: float64(12), int64(61), object(9)
# memory usage: 1.7+ GB

# %% [markdown]
# # Data Preprocessing

# %%
ev = df_.copy()

# %%
import numpy as np

ev['label_mul'] = ev['label_mul'].str.replace(r'\d+$', '', regex=True)
ev['label_bi'] = np.where(ev['label_mul'].isin(['idle benign', 'Charging Benign']), 0, 1)
ev['src_ip'] = ev['src_ip'].astype(str)+":"+ev['src_port'].astype(str)
ev['dst_ip'] = ev['dst_ip'].astype(str)+":"+ev['dst_port'].astype(str)
ev.drop(columns=['id', 'expiration_id', 'src_mac', 'src_oui', 'dst_mac', 'dst_oui', 'src_port','dst_port'], inplace=True)
ev.head()
# Out:
#                  src_ip               dst_ip  protocol  ip_version  vlan_id  \
# 0  192.168.137.85:42750  192.168.137.226:256         6           4        0
# 1  192.168.137.85:42750  192.168.137.226:993         6           4        0
# 2  192.168.137.85:42750  192.168.137.226:139         6           4        0
# 3  192.168.137.85:42750  192.168.137.226:143         6           4        0
# 4  192.168.137.85:42750  192.168.137.226:135         6           4        0
#
#    tunnel_id  bidirectional_first_seen_ms  bidirectional_last_seen_ms  \
# 0          0                1703261991666               1703261991779
# 1          0                1703261991667               1703261991784
# 2          0                1703261991667               1703261991784
# 3          0                1703261991667               1703261991785
# 4          0                1703261991667               1703261991785
#
#    bidirectional_duration_ms  bidirectional_packets  ...  dst2src_ack_packets  \
# 0                        113                      2  ...                    1
# 1                        117                      2  ...                    1
# 2                        117                      2  ...                    1
# 3                        118                      2  ...                    1
# 4                        118                      2  ...                    1
#
#    dst2src_psh_packets  dst2src_rst_packets  dst2src_fin_packets  \
# 0                    0                    1                    0
# 1                    0                    1                    0
# 2                    0                    1                    0
# 3                    0                    1                    0
# 4                    0                    1                    0
#
#    application_name  application_category_name  application_is_guessed  \
# 0           Unknown                Unspecified                       0
# 1             IMAPS                      Email                       1
# 2           NetBIOS                     System                       1
# 3              IMAP                      Email                       1
# 4               RPC                        RPC                       1
#
#    application_confidence                 label_mul  label_bi
# 0                       0  charging Aggressive scan         1
# 1                       1  charging Aggressive scan         1
# 2                       1  charging Aggressive scan         1
# 3                       1  charging Aggressive scan         1
# 4                       1  charging Aggressive scan         1
#
# [5 rows x 75 columns]

# %%
print(ev['label_mul'].unique())
print(ev['label_bi'].unique())
# Out:
# ['charging Aggressive scan' 'Charging Benign' 'charging icmp flood'
#  'charging icmp fragmentation' 'charging os fingerprinting'
#  'charging portscan' 'charging push ack flood'
#  'charging service detection' 'charging slowLoris scan'
#  'charging syn flood' 'charging syn stealth' 'charging synonymous ip'
#  'charging tcp flood' 'charging udp flood' 'charging vulnerability scan'
#  'idle aggressive scan' 'idle benign' 'idle icmp fragmentation'
#  'idle os fingerprinting' 'idle portscan' 'idle service detection'
#  'idle slowloris scan' 'idle syn flood' 'idle syn stealth scan'
#  'idle synonymous ip' 'idle tcp flood' 'idle udp flood'
#  'idle vulnerability scan' 'charging aggressive scan' 'charging port scan'
#  'charging service detection scan' 'charging synonymous ip flood'
#  'idle icmp flood' 'idle port scan' 'idle push ack flood'
#  'idle synonymous ip flood' 'MaliciousEV aggressive scan'
#  'MaliciousEV os fingerprinting' 'MaliciousEV port scan'
#  'MaliciousEV service detection' 'MaliciousEV syn stealth scan'
#  'MaliciousEV vulnerability scan']
# [1 0]

# %% [markdown]
# ## Label Mapping

# %%
# Original to new label mapping
label_mapping = {
    'charging Aggressive scan': 'aggressive-scan',
    'Charging Benign': 'None',
    'charging icmp flood': 'icmp-flood',
    'charging icmp fragmentation': 'icmp-fragmentation',
    'charging os fingerprinting': 'os-fingerpriting',
    'charging portscan': 'TCP-port-scan',
    'charging push ack flood': 'pshack-flood',
    'charging service detection': 'service-version-detection',
    'charging slowLoris scan': 'slowloris-scan',
    'charging syn flood': 'syn-flood',
    'charging syn stealth': 'syn-stealth-scan',
    'charging synonymous ip': 'synonymousIP-flood',
    'charging tcp flood': 'TCP-flood',
    'charging udp flood': 'upd-flood',
    'charging vulnerability scan': 'vulnerability-scan',
    'idle aggressive scan': 'aggressive-scan',
    'idle benign': 'None',
    'idle icmp fragmentation': 'icmp-fragmentation',
    'idle os fingerprinting': 'os-fingerpriting',
    'idle portscan': 'TCP-port-scan',
    'idle service detection': 'service-version-detection',
    'idle slowloris scan': 'slowloris-scan',
    'idle syn flood': 'syn-flood',
    'idle syn stealth scan': 'syn-stealth-scan',
    'idle synonymous ip': 'synonymousIP-flood',
    'idle tcp flood': 'TCP-flood',
    'idle udp flood': 'upd-flood',
    'idle vulnerability scan': 'vulnerability-scan',
    'charging aggressive scan': 'aggressive-scan',
    'charging port scan': 'TCP-port-scan',
    'charging service detection scan': 'service-version-detection',
    'charging synonymous ip flood': 'synonymousIP-flood',
    'idle icmp flood': 'icmp-flood',
    'idle port scan': 'TCP-port-scan',
    'idle push ack flood': 'pshack-flood',
    'idle synonymous ip flood': 'synonymousIP-flood',
    'MaliciousEV aggressive scan': 'aggressive-scan',
    'MaliciousEV os fingerprinting': 'os-fingerpriting',
    'MaliciousEV port scan': 'TCP-port-scan',
    'MaliciousEV service detection': 'service-version-detection',
    'MaliciousEV syn stealth scan': 'syn-stealth-scan',
    'MaliciousEV vulnerability scan': 'vulnerability-scan'
}

# Apply the mapping to the label_mul column
ev['label_mul'] = ev['label_mul'].map(label_mapping)

# Verify the mapping
print(ev['label_mul'].unique())
# Out:
# ['aggressive-scan' 'None' 'icmp-flood' 'icmp-fragmentation'
#  'os-fingerpriting' 'TCP-port-scan' 'pshack-flood'
#  'service-version-detection' 'slowloris-scan' 'syn-flood'
#  'syn-stealth-scan' 'synonymousIP-flood' 'TCP-flood' 'upd-flood'
#  'vulnerability-scan']

# %% [markdown]
# ## Drop Null Columns

# %%
ev['vlan_id'].unique(), ev['dst2src_cwr_packets'].unique(), ev['dst2src_urg_packets'].unique()
# Out:
# (array([0]), array([0]), array([0]))

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744700 entries, 0 to 2744699
# Data columns (total 75 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   src_ip                        object
#  1   dst_ip                        object
#  2   protocol                      int64
#  3   ip_version                    int64
#  4   vlan_id                       int64
#  5   tunnel_id                     int64
#  6   bidirectional_first_seen_ms   int64
#  7   bidirectional_last_seen_ms    int64
#  8   bidirectional_duration_ms     int64
#  9   bidirectional_packets         int64
#  10  bidirectional_bytes           int64
#  11  src2dst_first_seen_ms         int64
#  12  src2dst_last_seen_ms          int64
#  13  src2dst_duration_ms           int64
#  14  src2dst_packets               int64
#  15  src2dst_bytes                 int64
#  16  dst2src_first_seen_ms         int64
#  17  dst2src_last_seen_ms          int64
#  18  dst2src_duration_ms           int64
#  19  dst2src_packets               int64
#  20  dst2src_bytes                 int64
#  21  bidirectional_min_ps          int64
#  22  bidirectional_mean_ps         float64
#  23  bidirectional_stddev_ps       float64
#  24  bidirectional_max_ps          int64
#  25  src2dst_min_ps                int64
#  26  src2dst_mean_ps               float64
#  27  src2dst_stddev_ps             float64
#  28  src2dst_max_ps                int64
#  29  dst2src_min_ps                int64
#  30  dst2src_mean_ps               float64
#  31  dst2src_stddev_ps             float64
#  32  dst2src_max_ps                int64
#  33  bidirectional_min_piat_ms     int64
#  34  bidirectional_mean_piat_ms    float64
#  35  bidirectional_stddev_piat_ms  float64
#  36  bidirectional_max_piat_ms     int64
#  37  src2dst_min_piat_ms           int64
#  38  src2dst_mean_piat_ms          float64
#  39  src2dst_stddev_piat_ms        float64
#  40  src2dst_max_piat_ms           int64
#  41  dst2src_min_piat_ms           int64
#  42  dst2src_mean_piat_ms          float64
#  43  dst2src_stddev_piat_ms        float64
#  44  dst2src_max_piat_ms           int64
#  45  bidirectional_syn_packets     int64
#  46  bidirectional_cwr_packets     int64
#  47  bidirectional_ece_packets     int64
#  48  bidirectional_urg_packets     int64
#  49  bidirectional_ack_packets     int64
#  50  bidirectional_psh_packets     int64
#  51  bidirectional_rst_packets     int64
#  52  bidirectional_fin_packets     int64
#  53  src2dst_syn_packets           int64
#  54  src2dst_cwr_packets           int64
#  55  src2dst_ece_packets           int64
#  56  src2dst_urg_packets           int64
#  57  src2dst_ack_packets           int64
#  58  src2dst_psh_packets           int64
#  59  src2dst_rst_packets           int64
#  60  src2dst_fin_packets           int64
#  61  dst2src_syn_packets           int64
#  62  dst2src_cwr_packets           int64
#  63  dst2src_ece_packets           int64
#  64  dst2src_urg_packets           int64
#  65  dst2src_ack_packets           int64
#  66  dst2src_psh_packets           int64
#  67  dst2src_rst_packets           int64
#  68  dst2src_fin_packets           int64
#  69  application_name              object
#  70  application_category_name     object
#  71  application_is_guessed        int64
#  72  application_confidence        int64
#  73  label_mul                     object
#  74  label_bi                      int64
# dtypes: float64(12), int64(58), object(5)
# memory usage: 1.5+ GB

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# List of object columns to encode
object_columns = [
    "application_name",
    "application_category_name",
]

# Apply label encoding to each column
label_encoders = {}  # To store the encoders for each column
for col in object_columns:
    label_encoders[col] = LabelEncoder()  # Create a LabelEncoder for each column
    ev[col] = label_encoders[col].fit_transform(ev[col].astype(str))  # Encode the column

# Verify the result
print(ev[object_columns].head())
# Out:
#    application_name  application_category_name
# 0                61                         14
# 1                23                          5
# 2                35                         13
# 3                22                          5
# 4                42                         11

# %%
attack_mapping = {
    'aggressive-scan': 'Recon',
    'None': 'Benign',
    'icmp-flood': 'DoS',
    'icmp-fragmentation': 'DoS',
    'os-fingerpriting': 'Recon',
    'TCP-port-scan': 'Recon',
    'pshack-flood': 'DoS',
    'service-version-detection': 'Recon',
    'slowloris-scan': 'DoS',
    'syn-flood': 'DoS',
    'syn-stealth-scan': 'Recon',
    'synonymousIP-flood': 'DoS',
    'TCP-flood': 'DoS',
    'upd-flood': 'DoS',
    'vulnerability-scan': 'Recon'
}

# Map the 'Attack' column to the new categories
ev['Scenario'] = ev['label_mul'].map(attack_mapping)

# Verify the mapping
print(ev[['label_mul', 'Scenario']].head())
# Out:
#          label_mul Scenario
# 0  aggressive-scan    Recon
# 1  aggressive-scan    Recon
# 2  aggressive-scan    Recon
# 3  aggressive-scan    Recon
# 4  aggressive-scan    Recon

# %%
ev.drop(columns = ['label_mul'], inplace=True)

# %%
ev['Scenario'].replace({"Benign":0, "Recon":1, "DoS":2, "Cryptojacking":3, "Backdoor":4
}, inplace= True)
# Out:
# /tmp/ipykernel_2159933/3209854169.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ev['Scenario'].replace({"Benign":0, "Recon":1, "DoS":2, "Cryptojacking":3, "Backdoor":4
# /tmp/ipykernel_2159933/3209854169.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ev['Scenario'].replace({"Benign":0, "Recon":1, "DoS":2, "Cryptojacking":3, "Backdoor":4

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2744700 entries, 0 to 2744699
# Data columns (total 75 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   src_ip                        object
#  1   dst_ip                        object
#  2   protocol                      int64
#  3   ip_version                    int64
#  4   vlan_id                       int64
#  5   tunnel_id                     int64
#  6   bidirectional_first_seen_ms   int64
#  7   bidirectional_last_seen_ms    int64
#  8   bidirectional_duration_ms     int64
#  9   bidirectional_packets         int64
#  10  bidirectional_bytes           int64
#  11  src2dst_first_seen_ms         int64
#  12  src2dst_last_seen_ms          int64
#  13  src2dst_duration_ms           int64
#  14  src2dst_packets               int64
#  15  src2dst_bytes                 int64
#  16  dst2src_first_seen_ms         int64
#  17  dst2src_last_seen_ms          int64
#  18  dst2src_duration_ms           int64
#  19  dst2src_packets               int64
#  20  dst2src_bytes                 int64
#  21  bidirectional_min_ps          int64
#  22  bidirectional_mean_ps         float64
#  23  bidirectional_stddev_ps       float64
#  24  bidirectional_max_ps          int64
#  25  src2dst_min_ps                int64
#  26  src2dst_mean_ps               float64
#  27  src2dst_stddev_ps             float64
#  28  src2dst_max_ps                int64
#  29  dst2src_min_ps                int64
#  30  dst2src_mean_ps               float64
#  31  dst2src_stddev_ps             float64
#  32  dst2src_max_ps                int64
#  33  bidirectional_min_piat_ms     int64
#  34  bidirectional_mean_piat_ms    float64
#  35  bidirectional_stddev_piat_ms  float64
#  36  bidirectional_max_piat_ms     int64
#  37  src2dst_min_piat_ms           int64
#  38  src2dst_mean_piat_ms          float64
#  39  src2dst_stddev_piat_ms        float64
#  40  src2dst_max_piat_ms           int64
#  41  dst2src_min_piat_ms           int64
#  42  dst2src_mean_piat_ms          float64
#  43  dst2src_stddev_piat_ms        float64
#  44  dst2src_max_piat_ms           int64
#  45  bidirectional_syn_packets     int64
#  46  bidirectional_cwr_packets     int64
#  47  bidirectional_ece_packets     int64
#  48  bidirectional_urg_packets     int64
#  49  bidirectional_ack_packets     int64
#  50  bidirectional_psh_packets     int64
#  51  bidirectional_rst_packets     int64
#  52  bidirectional_fin_packets     int64
#  53  src2dst_syn_packets           int64
#  54  src2dst_cwr_packets           int64
#  55  src2dst_ece_packets           int64
#  56  src2dst_urg_packets           int64
#  57  src2dst_ack_packets           int64
#  58  src2dst_psh_packets           int64
#  59  src2dst_rst_packets           int64
#  60  src2dst_fin_packets           int64
#  61  dst2src_syn_packets           int64
#  62  dst2src_cwr_packets           int64
#  63  dst2src_ece_packets           int64
#  64  dst2src_urg_packets           int64
#  65  dst2src_ack_packets           int64
#  66  dst2src_psh_packets           int64
#  67  dst2src_rst_packets           int64
#  68  dst2src_fin_packets           int64
#  69  application_name              int64
#  70  application_category_name     int64
#  71  application_is_guessed        int64
#  72  application_confidence        int64
#  73  label_bi                      int64
#  74  Scenario                      int64
# dtypes: float64(12), int64(61), object(2)
# memory usage: 1.5+ GB

# %%
ev['Scenario'].unique()
# Out:
# array([1, 0, 2])

# %% [markdown]
# # GNN - All Features

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from tqdm import tqdm


all_ips = list(set(ev['src_ip']) | set(ev['dst_ip']))
ip_map = {ip: i for i, ip in enumerate(all_ips)}


a = [ip_map[ip] for ip in ev['src_ip']]
b = [ip_map[ip] for ip in ev['dst_ip']]
edge_index = torch.tensor([a, b], dtype=torch.long)

# use Learnable Embeddings for IP Addresses as Node Features
num_nodes = len(all_ips)
embedding_dim = 16  # Can be tuned
node_features = torch.nn.Embedding(num_nodes, embedding_dim)


edge_features = ev.iloc[:, 2:73].to_numpy()  # Edge Features (whole)
scaler = StandardScaler()
edge_features_standardized = scaler.fit_transform(edge_features)
edge_attr = torch.tensor(edge_features_standardized, dtype=torch.float)

# Step 5: Labels
labels = torch.tensor(ev['Scenario'].values, dtype=torch.long)

# %% [markdown]
# ### PCA Scatter Plot

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np

# Perform PCA to reduce edge features to 2D for visualization
pca = PCA(n_components=2)
edge_features_2d = pca.fit_transform(edge_features_standardized)

# Define label names (assuming three labels: Benign, Recon, DoS)
label_names = ["Benign", "Recon", "DoS"]

# Create a scatter plot of edge features in 2D space
plt.figure(figsize=(10, 8))

# Use labels to color the points
unique_labels = torch.unique(labels).numpy()
colors = plt.cm.Set2(np.linspace(0, 1, len(unique_labels)))

for i, label in enumerate(unique_labels):
    label_indices = (labels.numpy() == label)
    plt.scatter(
        edge_features_2d[label_indices, 0],  # PCA Dimension 1
        edge_features_2d[label_indices, 1],  # PCA Dimension 2
        color=colors[i],
        label=f"{label_names[label]}",
        alpha=0.6,
        s=40,
        edgecolor='k'  # Add black border for better visibility
    )

# Highlight cluster centers (mean position per label)
for i, label in enumerate(unique_labels):
    cluster_center = edge_features_2d[labels.numpy() == label].mean(axis=0)
    plt.scatter(
        cluster_center[0],
        cluster_center[1],
        color=colors[i],
        edgecolor='black',
        s=200,
        marker="X",
        label=f"{label_names[label]} Center"
    )

# Configure plot details
plt.title("PCA Visualization of Edge Features", fontsize=14)
plt.xlabel("PCA Dimension 1", fontsize=12)
plt.ylabel("PCA Dimension 2", fontsize=12)
plt.legend(title="Labels", fontsize=10, loc='upper right', frameon=True)
plt.grid(alpha=0.3, linestyle="--")
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Heatmap of PCA-Transformed Features

# %%
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Prepare 3D PCA data
pca_3d = PCA(n_components=3)
edge_features_3d = pca_3d.fit_transform(edge_features_standardized)

# Unique labels for grouping
unique_labels = np.unique(labels)

# Define colors
colors = plt.cm.Set2(np.linspace(0, 1, len(unique_labels)))

# --- HEATMAP: Pairwise distances/correlations ---
plt.figure(figsize=(10, 8))
heatmap_data = np.corrcoef(edge_features_2d.T)
sns.heatmap(heatmap_data, annot=False, cmap="coolwarm", square=True)
plt.title("Heatmap of PCA-Transformed Features", fontsize=14)
plt.xlabel("PCA Components", fontsize=12)
plt.ylabel("PCA Components", fontsize=12)
plt.show()

# %% [markdown]
# ### 3D Scatter plot of PCA Features

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")
for i, label in enumerate(unique_labels):
    label_indices = (labels == label)
    ax.scatter(
        edge_features_3d[label_indices, 0],  # PCA Dim 1
        edge_features_3d[label_indices, 1],  # PCA Dim 2
        edge_features_3d[label_indices, 2],  # PCA Dim 3
        color=colors[i],
        label=f"{label_names[label]}",
        alpha=0.7,
        s=40
    )
ax.set_title("3D Scatter Plot of PCA Features", fontsize=14)
ax.set_xlabel("PCA Dimension 1", fontsize=12)
ax.set_ylabel("PCA Dimension 2", fontsize=12)
ax.set_zlabel("PCA Dimension 3", fontsize=12)
ax.legend(title="Labels", fontsize=10, loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Violin Plot of PCA Features by Label

# %%
plt.figure(figsize=(12, 6))
for i in range(edge_features_2d.shape[1]):
    sns.violinplot(
        x=labels,
        y=edge_features_2d[:, i],
        palette="Set2",
        scale="width",
        inner="quartile",
        linewidth=1,
        bw=0.2
    )
plt.title("Violin Plot of PCA Features by Label", fontsize=14)
plt.xlabel("Labels", fontsize=12)
plt.ylabel("PCA Features", fontsize=12)
plt.xticks(ticks=np.arange(len(label_names)), labels=label_names, fontsize=10)
plt.grid(alpha=0.3, linestyle="--")
plt.show()
# Out:
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.2`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(
# /tmp/ipykernel_2159933/2900645023.py:4: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.2`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(

# %%
# Create PyG Data Object
data = Data(x=node_features.weight, edge_index=edge_index, edge_attr=edge_attr, y=labels)

# Split Dataset
num_edges = edge_index.shape[1]
indices = torch.randperm(num_edges)
split = int(0.8 * num_edges)
train_idx = indices[:split]
test_idx = indices[split:]

train_edge_index = edge_index[:, train_idx]
test_edge_index = edge_index[:, test_idx]

train_edge_attr = edge_attr[train_idx]
test_edge_attr = edge_attr[test_idx]

train_labels = labels[train_idx]
test_labels = labels[test_idx]

train_data = Data(x=node_features.weight, edge_index=train_edge_index, edge_attr=train_edge_attr, y=train_labels)
test_data = Data(x=node_features.weight, edge_index=test_edge_index, edge_attr=test_edge_attr, y=test_labels)

# DataLoader
train_loader = DataLoader([train_data], batch_size=32, shuffle=True)
test_loader = DataLoader([test_data], batch_size=32)

# %% [markdown]
# ## GNN - SAGE

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, GINConv, MessagePassing
from torch_geometric.data import Data

class EdgeGNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, gnn_type="SAGE"):
        super(EdgeGNN, self).__init__()

        if gnn_type == "GCN":
            self.conv1 = GCNConv(in_channels, hidden_channels)
            self.conv2 = GCNConv(hidden_channels, hidden_channels)
        elif gnn_type == "GAT":
            self.conv1 = GATConv(in_channels, hidden_channels, heads=2, concat=False)
            self.conv2 = GATConv(hidden_channels, hidden_channels, heads=2, concat=False)
        elif gnn_type == "GIN":
            self.conv1 = GINConv(torch.nn.Sequential(
                torch.nn.Linear(in_channels, hidden_channels),
                torch.nn.ReLU(),
                torch.nn.Linear(hidden_channels, hidden_channels)
            ))
            self.conv2 = GINConv(torch.nn.Sequential(
                torch.nn.Linear(hidden_channels, hidden_channels),
                torch.nn.ReLU(),
                torch.nn.Linear(hidden_channels, hidden_channels)
            ))
        elif gnn_type == "MPNN":
            class MPNNLayer(MessagePassing):
                def __init__(self, in_channels, out_channels):
                    super().__init__(aggr='mean')  # Aggregation function
                    self.linear = torch.nn.Linear(in_channels, out_channels)

                def forward(self, x, edge_index):
                    return self.linear(self.propagate(edge_index, x=x))

                def message(self, x_j):
                    return x_j

            self.conv1 = MPNNLayer(in_channels, hidden_channels)
            self.conv2 = MPNNLayer(hidden_channels, hidden_channels)
        elif gnn_type == "SAGE":  # Explicitly add GraphSAGE
            self.conv1 = SAGEConv(in_channels, hidden_channels)
            self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        else:
            raise ValueError("Invalid GNN type. Choose from ['GCN', 'GAT', 'GIN', 'MPNN', 'Graphormer', 'SAGE']")

        # Edge MLP Classifier
        self.edge_mlp = torch.nn.Linear(hidden_channels * 2 + edge_attr.shape[1], out_channels)

    def forward(self, x, edge_index, edge_attr):
        x = self.conv1(x, edge_index)
        x = self.conv2(x, edge_index)
        x = F.relu(x)

        # Compute Edge Embeddings
        src, dst = edge_index
        edge_embeddings = torch.cat([x[src], x[dst], edge_attr], dim=1)

        # Predict Edge Labels
        edge_logits = self.edge_mlp(edge_embeddings)
        return edge_logits



# Model, Optimizer, Loss
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gnn_type = "SAGE"

# Create Model
model = EdgeGNN(
    in_channels=embedding_dim,
    hidden_channels=32,
    out_channels=len(labels.unique()),
    gnn_type=gnn_type
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
class_counts = torch.bincount(labels)  # Count occurrences of each class
class_weights = 1.0 / class_counts.float()  # Inverse of frequency
class_weights = class_weights / class_weights.sum()  # Normalize
class_weights = class_weights.to(device)  # Move to GPU if needed
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

# %% [markdown]
# ### Train/Validation Accuracy and Loss

# %%
import matplotlib.pyplot as plt
# Plot loss and accuracy for both training and validation
plt.figure(figsize=(14, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(epochs), loss_list, label="Train Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.grid(True)
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(epochs), acc_list, label="Train Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("SAGE - Accuracy over Epochs")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
sage_loss_list = loss_list.copy()
sage_acc_list = acc_list.copy()

# %% [markdown]
# ### Test Evaluation

# %%
from sklearn.metrics import classification_report

model.eval()
correct, total = 0, 0
all_predictions = []
all_targets = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Store for classification report
        all_predictions.extend(predicted.cpu().numpy())
        all_targets.extend(batch.y.cpu().numpy())
target_names = ["Benign", "Recon", "DoS"]
test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy:.4f}")

# Print Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_predictions,  target_names= target_names, digits=4))
# Out:
# Test Accuracy: 0.9967
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign     0.0693    1.0000    0.1296        16
#        Recon     0.9983    0.9965    0.9974    345328
#          DoS     0.9950    0.9970    0.9960    203596
#
#     accuracy                         0.9967    548940
#    macro avg     0.6875    0.9978    0.7077    548940
# weighted avg     0.9971    0.9967    0.9969    548940

# %%
import torch
import gc

# Free up GPU memory
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## GAT

# %%
# Model, Optimizer, Loss
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gnn_type = "GAT"

# Create Model
model = EdgeGNN(
    in_channels=embedding_dim,
    hidden_channels=32,
    out_channels=len(labels.unique()),
    gnn_type=gnn_type
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

class_counts = torch.bincount(labels)  # Count occurrences of each class
class_weights = 1.0 / class_counts.float()  # Inverse of frequency
class_weights = class_weights / class_weights.sum()  # Normalize
class_weights = class_weights.to(device)  # Move to GPU if needed
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

# %%
# Train the Model
epochs = 100
loss_list, acc_list = [], []

for epoch in range(epochs):
    model.train()
    total_loss, correct, total = 0, 0, 0

    train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)
    for batch in train_loader_tqdm:
        batch = batch.to(device)
        optimizer.zero_grad()
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        loss = criterion(outputs, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # Compute Accuracy
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)
        train_loader_tqdm.set_postfix(loss=loss.item())

    avg_loss = total_loss / len(train_loader)
    train_accuracy = correct / total
    loss_list.append(avg_loss)
    acc_list.append(train_accuracy)
    print(f"Epoch {epoch+1}/{epochs}, Avg Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
# Out:
# Epoch 1/100, Avg Loss: 1.4811, Train Accuracy: 0.8003
# Epoch 2/100, Avg Loss: 1.1276, Train Accuracy: 0.8346
# Epoch 3/100, Avg Loss: 0.8881, Train Accuracy: 0.8502
# Epoch 4/100, Avg Loss: 0.7521, Train Accuracy: 0.8780
# Epoch 5/100, Avg Loss: 0.6707, Train Accuracy: 0.9003
# Epoch 6/100, Avg Loss: 0.6126, Train Accuracy: 0.9066
# Epoch 7/100, Avg Loss: 0.5668, Train Accuracy: 0.9275
# Epoch 8/100, Avg Loss: 0.5274, Train Accuracy: 0.9382
# Epoch 9/100, Avg Loss: 0.4909, Train Accuracy: 0.9439
# Epoch 10/100, Avg Loss: 0.4563, Train Accuracy: 0.9500
# Epoch 11/100, Avg Loss: 0.4237, Train Accuracy: 0.9565
# Epoch 12/100, Avg Loss: 0.3929, Train Accuracy: 0.9649
# Epoch 13/100, Avg Loss: 0.3631, Train Accuracy: 0.9759
# Epoch 14/100, Avg Loss: 0.3339, Train Accuracy: 0.9821
# Epoch 15/100, Avg Loss: 0.3049, Train Accuracy: 0.9847
# Epoch 16/100, Avg Loss: 0.2767, Train Accuracy: 0.9870
# Epoch 17/100, Avg Loss: 0.2496, Train Accuracy: 0.9904
# Epoch 18/100, Avg Loss: 0.2244, Train Accuracy: 0.9941
# Epoch 19/100, Avg Loss: 0.2019, Train Accuracy: 0.9948
# Epoch 20/100, Avg Loss: 0.1824, Train Accuracy: 0.9955
# Epoch 21/100, Avg Loss: 0.1662, Train Accuracy: 0.9956
# Epoch 22/100, Avg Loss: 0.1532, Train Accuracy: 0.9956
# Epoch 23/100, Avg Loss: 0.1434, Train Accuracy: 0.9953
# Epoch 24/100, Avg Loss: 0.1362, Train Accuracy: 0.9950
# Epoch 25/100, Avg Loss: 0.1304, Train Accuracy: 0.9948
# Epoch 26/100, Avg Loss: 0.1249, Train Accuracy: 0.9951
# Epoch 27/100, Avg Loss: 0.1193, Train Accuracy: 0.9955
# Epoch 28/100, Avg Loss: 0.1137, Train Accuracy: 0.9959
# Epoch 29/100, Avg Loss: 0.1085, Train Accuracy: 0.9963
# Epoch 30/100, Avg Loss: 0.1039, Train Accuracy: 0.9966
# Epoch 31/100, Avg Loss: 0.0995, Train Accuracy: 0.9962
# Epoch 32/100, Avg Loss: 0.0948, Train Accuracy: 0.9960
# Epoch 33/100, Avg Loss: 0.0897, Train Accuracy: 0.9961
# Epoch 34/100, Avg Loss: 0.0847, Train Accuracy: 0.9965
# Epoch 35/100, Avg Loss: 0.0801, Train Accuracy: 0.9968
# Epoch 36/100, Avg Loss: 0.0758, Train Accuracy: 0.9969
# Epoch 37/100, Avg Loss: 0.0716, Train Accuracy: 0.9969
# Epoch 38/100, Avg Loss: 0.0674, Train Accuracy: 0.9969
# Epoch 39/100, Avg Loss: 0.0631, Train Accuracy: 0.9966
# Epoch 40/100, Avg Loss: 0.0592, Train Accuracy: 0.9961
# Epoch 41/100, Avg Loss: 0.0558, Train Accuracy: 0.9956
# Epoch 42/100, Avg Loss: 0.0527, Train Accuracy: 0.9955
# Epoch 43/100, Avg Loss: 0.0499, Train Accuracy: 0.9954
# Epoch 44/100, Avg Loss: 0.0474, Train Accuracy: 0.9953
# Epoch 45/100, Avg Loss: 0.0453, Train Accuracy: 0.9953
# Epoch 46/100, Avg Loss: 0.0435, Train Accuracy: 0.9953
# Epoch 47/100, Avg Loss: 0.0419, Train Accuracy: 0.9953
# Epoch 48/100, Avg Loss: 0.0405, Train Accuracy: 0.9954
# Epoch 49/100, Avg Loss: 0.0392, Train Accuracy: 0.9954
# Epoch 50/100, Avg Loss: 0.0381, Train Accuracy: 0.9954
# Epoch 51/100, Avg Loss: 0.0371, Train Accuracy: 0.9953
# Epoch 52/100, Avg Loss: 0.0361, Train Accuracy: 0.9952
# Epoch 53/100, Avg Loss: 0.0353, Train Accuracy: 0.9951
# Epoch 54/100, Avg Loss: 0.0345, Train Accuracy: 0.9949
# Epoch 55/100, Avg Loss: 0.0338, Train Accuracy: 0.9947
# Epoch 56/100, Avg Loss: 0.0332, Train Accuracy: 0.9946
# Epoch 57/100, Avg Loss: 0.0326, Train Accuracy: 0.9946
# Epoch 58/100, Avg Loss: 0.0321, Train Accuracy: 0.9948
# Epoch 59/100, Avg Loss: 0.0316, Train Accuracy: 0.9949
# Epoch 60/100, Avg Loss: 0.0312, Train Accuracy: 0.9952
# Epoch 61/100, Avg Loss: 0.0307, Train Accuracy: 0.9954
# Epoch 62/100, Avg Loss: 0.0303, Train Accuracy: 0.9955
# Epoch 63/100, Avg Loss: 0.0300, Train Accuracy: 0.9955
# Epoch 64/100, Avg Loss: 0.0296, Train Accuracy: 0.9955
# Epoch 65/100, Avg Loss: 0.0293, Train Accuracy: 0.9955
# Epoch 66/100, Avg Loss: 0.0289, Train Accuracy: 0.9956
# Epoch 67/100, Avg Loss: 0.0286, Train Accuracy: 0.9956
# Epoch 68/100, Avg Loss: 0.0284, Train Accuracy: 0.9956
# Epoch 69/100, Avg Loss: 0.0281, Train Accuracy: 0.9956
# Epoch 70/100, Avg Loss: 0.0278, Train Accuracy: 0.9956
# Epoch 71/100, Avg Loss: 0.0275, Train Accuracy: 0.9957
# Epoch 72/100, Avg Loss: 0.0272, Train Accuracy: 0.9957
# Epoch 73/100, Avg Loss: 0.0270, Train Accuracy: 0.9957
# Epoch 74/100, Avg Loss: 0.0267, Train Accuracy: 0.9957
# Epoch 75/100, Avg Loss: 0.0265, Train Accuracy: 0.9958
# Epoch 76/100, Avg Loss: 0.0262, Train Accuracy: 0.9958
# Epoch 77/100, Avg Loss: 0.0260, Train Accuracy: 0.9958
# Epoch 78/100, Avg Loss: 0.0257, Train Accuracy: 0.9959
# Epoch 79/100, Avg Loss: 0.0255, Train Accuracy: 0.9959
# Epoch 80/100, Avg Loss: 0.0252, Train Accuracy: 0.9960
# Epoch 81/100, Avg Loss: 0.0250, Train Accuracy: 0.9960
# Epoch 82/100, Avg Loss: 0.0248, Train Accuracy: 0.9960
# Epoch 83/100, Avg Loss: 0.0245, Train Accuracy: 0.9961
# Epoch 84/100, Avg Loss: 0.0243, Train Accuracy: 0.9961
# Epoch 85/100, Avg Loss: 0.0241, Train Accuracy: 0.9961
# Epoch 86/100, Avg Loss: 0.0239, Train Accuracy: 0.9961
# Epoch 87/100, Avg Loss: 0.0236, Train Accuracy: 0.9962
# Epoch 88/100, Avg Loss: 0.0234, Train Accuracy: 0.9962
# Epoch 89/100, Avg Loss: 0.0232, Train Accuracy: 0.9962
# Epoch 90/100, Avg Loss: 0.0230, Train Accuracy: 0.9962
# Epoch 91/100, Avg Loss: 0.0228, Train Accuracy: 0.9962
# Epoch 92/100, Avg Loss: 0.0226, Train Accuracy: 0.9962
# Epoch 93/100, Avg Loss: 0.0223, Train Accuracy: 0.9962
# Epoch 94/100, Avg Loss: 0.0221, Train Accuracy: 0.9962
# Epoch 95/100, Avg Loss: 0.0219, Train Accuracy: 0.9963
# Epoch 96/100, Avg Loss: 0.0217, Train Accuracy: 0.9963
# Epoch 97/100, Avg Loss: 0.0215, Train Accuracy: 0.9963
# Epoch 98/100, Avg Loss: 0.0213, Train Accuracy: 0.9963
# Epoch 99/100, Avg Loss: 0.0211, Train Accuracy: 0.9963
# Epoch 100/100, Avg Loss: 0.0209, Train Accuracy: 0.9963

# %%
import matplotlib.pyplot as plt
# Plot loss and accuracy for both training and validation
plt.figure(figsize=(14, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(epochs), loss_list, label="Train Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.grid(True)
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(epochs), acc_list, label="Train Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epochs")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
gat_loss_list = loss_list.copy()
gat_acc_list = acc_list.copy()

# %%
from sklearn.metrics import classification_report

model.eval()
correct, total = 0, 0
all_predictions = []
all_targets = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Store for classification report
        all_predictions.extend(predicted.cpu().numpy())
        all_targets.extend(batch.y.cpu().numpy())
target_names = ["Benign", "Recon", "DoS"]
test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy:.4f}")

# Print Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_predictions,  target_names= target_names, digits=4))
# Out:
# Test Accuracy: 0.9908
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign     0.1368    1.0000    0.2406        16
#        Recon     0.9891    0.9964    0.9928    345328
#          DoS     0.9942    0.9812    0.9877    203596
#
#     accuracy                         0.9908    548940
#    macro avg     0.7067    0.9926    0.7403    548940
# weighted avg     0.9910    0.9908    0.9908    548940

# %% [markdown]
# ## GCN

# %%
# Model, Optimizer, Loss
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gnn_type = "GCN"

# Create Model
model = EdgeGNN(
    in_channels=embedding_dim,
    hidden_channels=32,
    out_channels=len(labels.unique()),
    gnn_type=gnn_type
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

class_counts = torch.bincount(labels)  # Count occurrences of each class
class_weights = 1.0 / class_counts.float()  # Inverse of frequency
class_weights = class_weights / class_weights.sum()  # Normalize
class_weights = class_weights.to(device)  # Move to GPU if needed
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

# %%
# Train the Model
epochs = 100
loss_list, acc_list = [], []

for epoch in range(epochs):
    model.train()
    total_loss, correct, total = 0, 0, 0

    train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)
    for batch in train_loader_tqdm:
        batch = batch.to(device)
        optimizer.zero_grad()
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        loss = criterion(outputs, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # Compute Accuracy
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)
        train_loader_tqdm.set_postfix(loss=loss.item())

    avg_loss = total_loss / len(train_loader)
    train_accuracy = correct / total
    loss_list.append(avg_loss)
    acc_list.append(train_accuracy)
    print(f"Epoch {epoch+1}/{epochs}, Avg Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
# Out:
# Epoch 1/100, Avg Loss: 1.2787, Train Accuracy: 0.4145
# Epoch 2/100, Avg Loss: 0.8416, Train Accuracy: 0.6116
# Epoch 3/100, Avg Loss: 0.6066, Train Accuracy: 0.6873
# Epoch 4/100, Avg Loss: 0.4727, Train Accuracy: 0.7388
# Epoch 5/100, Avg Loss: 0.3828, Train Accuracy: 0.7781
# Epoch 6/100, Avg Loss: 0.3199, Train Accuracy: 0.8122
# Epoch 7/100, Avg Loss: 0.2805, Train Accuracy: 0.8471
# Epoch 8/100, Avg Loss: 0.2487, Train Accuracy: 0.8878
# Epoch 9/100, Avg Loss: 0.2196, Train Accuracy: 0.9307
# Epoch 10/100, Avg Loss: 0.1929, Train Accuracy: 0.9633
# Epoch 11/100, Avg Loss: 0.1688, Train Accuracy: 0.9784
# Epoch 12/100, Avg Loss: 0.1474, Train Accuracy: 0.9829
# Epoch 13/100, Avg Loss: 0.1290, Train Accuracy: 0.9840
# Epoch 14/100, Avg Loss: 0.1134, Train Accuracy: 0.9843
# Epoch 15/100, Avg Loss: 0.1004, Train Accuracy: 0.9844
# Epoch 16/100, Avg Loss: 0.0899, Train Accuracy: 0.9845
# Epoch 17/100, Avg Loss: 0.0820, Train Accuracy: 0.9845
# Epoch 18/100, Avg Loss: 0.0766, Train Accuracy: 0.9845
# Epoch 19/100, Avg Loss: 0.0736, Train Accuracy: 0.9844
# Epoch 20/100, Avg Loss: 0.0710, Train Accuracy: 0.9843
# Epoch 21/100, Avg Loss: 0.0671, Train Accuracy: 0.9843
# Epoch 22/100, Avg Loss: 0.0626, Train Accuracy: 0.9845
# Epoch 23/100, Avg Loss: 0.0589, Train Accuracy: 0.9847
# Epoch 24/100, Avg Loss: 0.0561, Train Accuracy: 0.9849
# Epoch 25/100, Avg Loss: 0.0542, Train Accuracy: 0.9850
# Epoch 26/100, Avg Loss: 0.0527, Train Accuracy: 0.9852
# Epoch 27/100, Avg Loss: 0.0514, Train Accuracy: 0.9854
# Epoch 28/100, Avg Loss: 0.0502, Train Accuracy: 0.9857
# Epoch 29/100, Avg Loss: 0.0491, Train Accuracy: 0.9860
# Epoch 30/100, Avg Loss: 0.0479, Train Accuracy: 0.9862
# Epoch 31/100, Avg Loss: 0.0468, Train Accuracy: 0.9865
# Epoch 32/100, Avg Loss: 0.0455, Train Accuracy: 0.9869
# Epoch 33/100, Avg Loss: 0.0443, Train Accuracy: 0.9872
# Epoch 34/100, Avg Loss: 0.0430, Train Accuracy: 0.9875
# Epoch 35/100, Avg Loss: 0.0418, Train Accuracy: 0.9879
# Epoch 36/100, Avg Loss: 0.0407, Train Accuracy: 0.9883
# Epoch 37/100, Avg Loss: 0.0397, Train Accuracy: 0.9887
# Epoch 38/100, Avg Loss: 0.0388, Train Accuracy: 0.9890
# Epoch 39/100, Avg Loss: 0.0380, Train Accuracy: 0.9893
# Epoch 40/100, Avg Loss: 0.0372, Train Accuracy: 0.9897
# Epoch 41/100, Avg Loss: 0.0362, Train Accuracy: 0.9900
# Epoch 42/100, Avg Loss: 0.0352, Train Accuracy: 0.9904
# Epoch 43/100, Avg Loss: 0.0342, Train Accuracy: 0.9907
# Epoch 44/100, Avg Loss: 0.0332, Train Accuracy: 0.9910
# Epoch 45/100, Avg Loss: 0.0324, Train Accuracy: 0.9913
# Epoch 46/100, Avg Loss: 0.0316, Train Accuracy: 0.9916
# Epoch 47/100, Avg Loss: 0.0308, Train Accuracy: 0.9919
# Epoch 48/100, Avg Loss: 0.0301, Train Accuracy: 0.9922
# Epoch 49/100, Avg Loss: 0.0294, Train Accuracy: 0.9925
# Epoch 50/100, Avg Loss: 0.0286, Train Accuracy: 0.9927
# Epoch 51/100, Avg Loss: 0.0279, Train Accuracy: 0.9930
# Epoch 52/100, Avg Loss: 0.0272, Train Accuracy: 0.9932
# Epoch 53/100, Avg Loss: 0.0265, Train Accuracy: 0.9934
# Epoch 54/100, Avg Loss: 0.0259, Train Accuracy: 0.9936
# Epoch 55/100, Avg Loss: 0.0253, Train Accuracy: 0.9938
# Epoch 56/100, Avg Loss: 0.0248, Train Accuracy: 0.9940
# Epoch 57/100, Avg Loss: 0.0243, Train Accuracy: 0.9942
# Epoch 58/100, Avg Loss: 0.0237, Train Accuracy: 0.9944
# Epoch 59/100, Avg Loss: 0.0232, Train Accuracy: 0.9945
# Epoch 60/100, Avg Loss: 0.0227, Train Accuracy: 0.9947
# Epoch 61/100, Avg Loss: 0.0223, Train Accuracy: 0.9948
# Epoch 62/100, Avg Loss: 0.0218, Train Accuracy: 0.9950
# Epoch 63/100, Avg Loss: 0.0214, Train Accuracy: 0.9952
# Epoch 64/100, Avg Loss: 0.0210, Train Accuracy: 0.9953
# Epoch 65/100, Avg Loss: 0.0207, Train Accuracy: 0.9955
# Epoch 66/100, Avg Loss: 0.0203, Train Accuracy: 0.9956
# Epoch 67/100, Avg Loss: 0.0200, Train Accuracy: 0.9957
# Epoch 68/100, Avg Loss: 0.0196, Train Accuracy: 0.9959
# Epoch 69/100, Avg Loss: 0.0193, Train Accuracy: 0.9960
# Epoch 70/100, Avg Loss: 0.0190, Train Accuracy: 0.9961
# Epoch 71/100, Avg Loss: 0.0187, Train Accuracy: 0.9961
# Epoch 72/100, Avg Loss: 0.0185, Train Accuracy: 0.9962
# Epoch 73/100, Avg Loss: 0.0182, Train Accuracy: 0.9962
# Epoch 74/100, Avg Loss: 0.0180, Train Accuracy: 0.9963
# Epoch 75/100, Avg Loss: 0.0177, Train Accuracy: 0.9965
# Epoch 76/100, Avg Loss: 0.0175, Train Accuracy: 0.9966
# Epoch 77/100, Avg Loss: 0.0173, Train Accuracy: 0.9967
# Epoch 78/100, Avg Loss: 0.0171, Train Accuracy: 0.9968
# Epoch 79/100, Avg Loss: 0.0170, Train Accuracy: 0.9968
# Epoch 80/100, Avg Loss: 0.0168, Train Accuracy: 0.9969
# Epoch 81/100, Avg Loss: 0.0166, Train Accuracy: 0.9969
# Epoch 82/100, Avg Loss: 0.0165, Train Accuracy: 0.9969
# Epoch 83/100, Avg Loss: 0.0163, Train Accuracy: 0.9970
# Epoch 84/100, Avg Loss: 0.0162, Train Accuracy: 0.9970
# Epoch 85/100, Avg Loss: 0.0161, Train Accuracy: 0.9970
# Epoch 86/100, Avg Loss: 0.0159, Train Accuracy: 0.9970
# Epoch 87/100, Avg Loss: 0.0158, Train Accuracy: 0.9971
# Epoch 88/100, Avg Loss: 0.0157, Train Accuracy: 0.9971
# Epoch 89/100, Avg Loss: 0.0156, Train Accuracy: 0.9971
# Epoch 90/100, Avg Loss: 0.0155, Train Accuracy: 0.9971
# Epoch 91/100, Avg Loss: 0.0154, Train Accuracy: 0.9971
# Epoch 92/100, Avg Loss: 0.0152, Train Accuracy: 0.9971
# Epoch 93/100, Avg Loss: 0.0151, Train Accuracy: 0.9971
# Epoch 94/100, Avg Loss: 0.0151, Train Accuracy: 0.9972
# Epoch 95/100, Avg Loss: 0.0150, Train Accuracy: 0.9972
# Epoch 96/100, Avg Loss: 0.0149, Train Accuracy: 0.9972
# Epoch 97/100, Avg Loss: 0.0148, Train Accuracy: 0.9972
# Epoch 98/100, Avg Loss: 0.0147, Train Accuracy: 0.9972
# Epoch 99/100, Avg Loss: 0.0146, Train Accuracy: 0.9972
# Epoch 100/100, Avg Loss: 0.0145, Train Accuracy: 0.9972

# %%
import matplotlib.pyplot as plt
# Plot loss and accuracy for both training and validation
plt.figure(figsize=(14, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(epochs), loss_list, label="Train Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.grid(True)
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(epochs), acc_list, label="Train Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epochs")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
gcn_loss_list = loss_list.copy()
gcn_acc_list = acc_list.copy()

# %%
from sklearn.metrics import classification_report

model.eval()
correct, total = 0, 0
all_predictions = []
all_targets = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Store for classification report
        all_predictions.extend(predicted.cpu().numpy())
        all_targets.extend(batch.y.cpu().numpy())
target_names = ["Benign", "Recon", "DoS"]
test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy:.4f}")

# Print Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_predictions,  target_names= target_names, digits=4))
# Out:
# Test Accuracy: 0.9856
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign     0.0976    1.0000    0.1778        16
#        Recon     0.9804    0.9972    0.9887    345328
#          DoS     0.9956    0.9661    0.9806    203596
#
#     accuracy                         0.9856    548940
#    macro avg     0.6912    0.9878    0.7157    548940
# weighted avg     0.9860    0.9856    0.9857    548940

# %% [markdown]
# ## MPNN

# %%
# Model, Optimizer, Loss
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
gnn_type = "MPNN"

# Create Model
model = EdgeGNN(
    in_channels=embedding_dim,
    hidden_channels=32,
    out_channels=len(labels.unique()),
    gnn_type=gnn_type
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

class_counts = torch.bincount(labels)  # Count occurrences of each class
class_weights = 1.0 / class_counts.float()  # Inverse of frequency
class_weights = class_weights / class_weights.sum()  # Normalize
class_weights = class_weights.to(device)  # Move to GPU if needed
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

# %%
# Train the Model
epochs = 100
loss_list, acc_list = [], []

for epoch in range(epochs):
    model.train()
    total_loss, correct, total = 0, 0, 0

    train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)
    for batch in train_loader_tqdm:
        batch = batch.to(device)
        optimizer.zero_grad()
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        loss = criterion(outputs, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # Compute Accuracy
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)
        train_loader_tqdm.set_postfix(loss=loss.item())

    avg_loss = total_loss / len(train_loader)
    train_accuracy = correct / total
    loss_list.append(avg_loss)
    acc_list.append(train_accuracy)
    print(f"Epoch {epoch+1}/{epochs}, Avg Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")
# Out:
# Epoch 1/100, Avg Loss: 1.1611, Train Accuracy: 0.3279
# Epoch 2/100, Avg Loss: 0.9440, Train Accuracy: 0.3891
# Epoch 3/100, Avg Loss: 0.8082, Train Accuracy: 0.4794
# Epoch 4/100, Avg Loss: 0.7175, Train Accuracy: 0.7182
# Epoch 5/100, Avg Loss: 0.6542, Train Accuracy: 0.8472
# Epoch 6/100, Avg Loss: 0.6056, Train Accuracy: 0.9207
# Epoch 7/100, Avg Loss: 0.5641, Train Accuracy: 0.9464
# Epoch 8/100, Avg Loss: 0.5269, Train Accuracy: 0.9759
# Epoch 9/100, Avg Loss: 0.4929, Train Accuracy: 0.9887
# Epoch 10/100, Avg Loss: 0.4615, Train Accuracy: 0.9958
# Epoch 11/100, Avg Loss: 0.4324, Train Accuracy: 0.9965
# Epoch 12/100, Avg Loss: 0.4053, Train Accuracy: 0.9967
# Epoch 13/100, Avg Loss: 0.3797, Train Accuracy: 0.9969
# Epoch 14/100, Avg Loss: 0.3558, Train Accuracy: 0.9969
# Epoch 15/100, Avg Loss: 0.3334, Train Accuracy: 0.9970
# Epoch 16/100, Avg Loss: 0.3123, Train Accuracy: 0.9970
# Epoch 17/100, Avg Loss: 0.2925, Train Accuracy: 0.9970
# Epoch 18/100, Avg Loss: 0.2740, Train Accuracy: 0.9970
# Epoch 19/100, Avg Loss: 0.2566, Train Accuracy: 0.9970
# Epoch 20/100, Avg Loss: 0.2405, Train Accuracy: 0.9970
# Epoch 21/100, Avg Loss: 0.2254, Train Accuracy: 0.9970
# Epoch 22/100, Avg Loss: 0.2113, Train Accuracy: 0.9970
# Epoch 23/100, Avg Loss: 0.1982, Train Accuracy: 0.9970
# Epoch 24/100, Avg Loss: 0.1859, Train Accuracy: 0.9970
# Epoch 25/100, Avg Loss: 0.1745, Train Accuracy: 0.9970
# Epoch 26/100, Avg Loss: 0.1639, Train Accuracy: 0.9970
# Epoch 27/100, Avg Loss: 0.1541, Train Accuracy: 0.9970
# Epoch 28/100, Avg Loss: 0.1450, Train Accuracy: 0.9971
# Epoch 29/100, Avg Loss: 0.1366, Train Accuracy: 0.9971
# Epoch 30/100, Avg Loss: 0.1290, Train Accuracy: 0.9971
# Epoch 31/100, Avg Loss: 0.1220, Train Accuracy: 0.9971
# Epoch 32/100, Avg Loss: 0.1157, Train Accuracy: 0.9971
# Epoch 33/100, Avg Loss: 0.1099, Train Accuracy: 0.9971
# Epoch 34/100, Avg Loss: 0.1048, Train Accuracy: 0.9971
# Epoch 35/100, Avg Loss: 0.1001, Train Accuracy: 0.9972
# Epoch 36/100, Avg Loss: 0.0960, Train Accuracy: 0.9972
# Epoch 37/100, Avg Loss: 0.0923, Train Accuracy: 0.9972
# Epoch 38/100, Avg Loss: 0.0890, Train Accuracy: 0.9972
# Epoch 39/100, Avg Loss: 0.0861, Train Accuracy: 0.9972
# Epoch 40/100, Avg Loss: 0.0835, Train Accuracy: 0.9973
# Epoch 41/100, Avg Loss: 0.0812, Train Accuracy: 0.9973
# Epoch 42/100, Avg Loss: 0.0791, Train Accuracy: 0.9973
# Epoch 43/100, Avg Loss: 0.0772, Train Accuracy: 0.9973
# Epoch 44/100, Avg Loss: 0.0754, Train Accuracy: 0.9973
# Epoch 45/100, Avg Loss: 0.0738, Train Accuracy: 0.9972
# Epoch 46/100, Avg Loss: 0.0723, Train Accuracy: 0.9972
# Epoch 47/100, Avg Loss: 0.0709, Train Accuracy: 0.9972
# Epoch 48/100, Avg Loss: 0.0695, Train Accuracy: 0.9972
# Epoch 49/100, Avg Loss: 0.0682, Train Accuracy: 0.9972
# Epoch 50/100, Avg Loss: 0.0670, Train Accuracy: 0.9972
# Epoch 51/100, Avg Loss: 0.0659, Train Accuracy: 0.9972
# Epoch 52/100, Avg Loss: 0.0649, Train Accuracy: 0.9971
# Epoch 53/100, Avg Loss: 0.0640, Train Accuracy: 0.9971
# Epoch 54/100, Avg Loss: 0.0631, Train Accuracy: 0.9971
# Epoch 55/100, Avg Loss: 0.0623, Train Accuracy: 0.9971
# Epoch 56/100, Avg Loss: 0.0615, Train Accuracy: 0.9971
# Epoch 57/100, Avg Loss: 0.0607, Train Accuracy: 0.9972
# Epoch 58/100, Avg Loss: 0.0600, Train Accuracy: 0.9972
# Epoch 59/100, Avg Loss: 0.0592, Train Accuracy: 0.9973
# Epoch 60/100, Avg Loss: 0.0585, Train Accuracy: 0.9973
# Epoch 61/100, Avg Loss: 0.0578, Train Accuracy: 0.9973
# Epoch 62/100, Avg Loss: 0.0572, Train Accuracy: 0.9973
# Epoch 63/100, Avg Loss: 0.0565, Train Accuracy: 0.9973
# Epoch 64/100, Avg Loss: 0.0559, Train Accuracy: 0.9973
# Epoch 65/100, Avg Loss: 0.0553, Train Accuracy: 0.9973
# Epoch 66/100, Avg Loss: 0.0547, Train Accuracy: 0.9973
# Epoch 67/100, Avg Loss: 0.0542, Train Accuracy: 0.9973
# Epoch 68/100, Avg Loss: 0.0537, Train Accuracy: 0.9973
# Epoch 69/100, Avg Loss: 0.0532, Train Accuracy: 0.9973
# Epoch 70/100, Avg Loss: 0.0527, Train Accuracy: 0.9973
# Epoch 71/100, Avg Loss: 0.0522, Train Accuracy: 0.9973
# Epoch 72/100, Avg Loss: 0.0517, Train Accuracy: 0.9973
# Epoch 73/100, Avg Loss: 0.0513, Train Accuracy: 0.9973
# Epoch 74/100, Avg Loss: 0.0508, Train Accuracy: 0.9973
# Epoch 75/100, Avg Loss: 0.0504, Train Accuracy: 0.9973
# Epoch 76/100, Avg Loss: 0.0500, Train Accuracy: 0.9973
# Epoch 77/100, Avg Loss: 0.0495, Train Accuracy: 0.9973
# Epoch 78/100, Avg Loss: 0.0491, Train Accuracy: 0.9973
# Epoch 79/100, Avg Loss: 0.0487, Train Accuracy: 0.9973
# Epoch 80/100, Avg Loss: 0.0483, Train Accuracy: 0.9973
# Epoch 81/100, Avg Loss: 0.0479, Train Accuracy: 0.9973
# Epoch 82/100, Avg Loss: 0.0476, Train Accuracy: 0.9973
# Epoch 83/100, Avg Loss: 0.0472, Train Accuracy: 0.9973
# Epoch 84/100, Avg Loss: 0.0468, Train Accuracy: 0.9973
# Epoch 85/100, Avg Loss: 0.0464, Train Accuracy: 0.9973
# Epoch 86/100, Avg Loss: 0.0461, Train Accuracy: 0.9973
# Epoch 87/100, Avg Loss: 0.0457, Train Accuracy: 0.9973
# Epoch 88/100, Avg Loss: 0.0454, Train Accuracy: 0.9973
# Epoch 89/100, Avg Loss: 0.0450, Train Accuracy: 0.9973
# Epoch 90/100, Avg Loss: 0.0447, Train Accuracy: 0.9973
# Epoch 91/100, Avg Loss: 0.0444, Train Accuracy: 0.9973
# Epoch 92/100, Avg Loss: 0.0440, Train Accuracy: 0.9973
# Epoch 93/100, Avg Loss: 0.0437, Train Accuracy: 0.9973
# Epoch 94/100, Avg Loss: 0.0434, Train Accuracy: 0.9973
# Epoch 95/100, Avg Loss: 0.0431, Train Accuracy: 0.9973
# Epoch 96/100, Avg Loss: 0.0427, Train Accuracy: 0.9973
# Epoch 97/100, Avg Loss: 0.0424, Train Accuracy: 0.9973
# Epoch 98/100, Avg Loss: 0.0421, Train Accuracy: 0.9973
# Epoch 99/100, Avg Loss: 0.0418, Train Accuracy: 0.9973
# Epoch 100/100, Avg Loss: 0.0415, Train Accuracy: 0.9973

# %%
import matplotlib.pyplot as plt
# Plot loss and accuracy for both training and validation
plt.figure(figsize=(14, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(epochs), loss_list, label="Train Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.grid(True)
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(epochs), acc_list, label="Train Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epochs")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
mpnn_loss_list = loss_list.copy()
mpnn_acc_list = acc_list.copy()

# %%
from sklearn.metrics import classification_report

model.eval()
correct, total = 0, 0
all_predictions = []
all_targets = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Store for classification report
        all_predictions.extend(predicted.cpu().numpy())
        all_targets.extend(batch.y.cpu().numpy())
target_names = ["Benign", "Recon", "DoS"]
test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy:.4f}")

# Print Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_predictions,  target_names= target_names, digits=4))
# Out:
# Test Accuracy: 0.9975
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign     0.0637    1.0000    0.1199        16
#        Recon     0.9987    0.9974    0.9981    345328
#          DoS     0.9966    0.9977    0.9971    203596
#
#     accuracy                         0.9975    548940
#    macro avg     0.6864    0.9984    0.7050    548940
# weighted avg     0.9979    0.9975    0.9977    548940

# %% [markdown]
# ## Graph-transformer

# %%
os.getcwd()
# Out:
# '/workspace/CICEVSE2024/Graphormer'

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import TransformerConv

class GraphTransformer(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_heads=4, num_layers=2):
        super(GraphTransformer, self).__init__()
        
        self.num_heads = num_heads
        self.hidden_dim = hidden_channels

        # Add an edge attribute projection layer
        self.edge_encoder = torch.nn.Linear(edge_attr.shape[1], hidden_channels * num_heads)

        # Initialize TransformerConv layers
        self.layers = torch.nn.ModuleList()
        self.layers.append(TransformerConv(in_channels, hidden_channels, heads=num_heads, concat=True))
        for _ in range(num_layers - 1):
            self.layers.append(TransformerConv(hidden_channels * num_heads, hidden_channels, heads=num_heads, concat=True))
        
        # Dynamically compute input size for edge_mlp
        self.edge_mlp_input_dim = 2 * (hidden_channels * 2 + (hidden_channels * num_heads))
        self.edge_mlp = torch.nn.Linear(self.edge_mlp_input_dim, out_channels)
    def forward(self, x, edge_index, edge_attr):
        # Project edge_attr to the required size
        if edge_attr is not None:
            # Project edge_attr to [num_edges, hidden_dim * num_heads]
            edge_attr = self.edge_encoder(edge_attr)
            
            # Reshape edge_attr to [num_edges, num_heads, hidden_dim]
            edge_attr = edge_attr.view(-1, self.num_heads, self.hidden_dim)
    
        # Pass through TransformerConv layers
        for layer in self.layers:
            x = F.relu(layer(x, edge_index, edge_attr))
        
        # Compute Edge Embeddings
        src, dst = edge_index
        edge_embeddings = torch.cat([x[src], x[dst], edge_attr.view(-1, self.hidden_dim * self.num_heads)], dim=1)
        
        
        # Predict Edge Labels
        edge_logits = self.edge_mlp(edge_embeddings)
        return edge_logits



# Initialize the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GraphTransformer(
    in_channels=node_features.embedding_dim,  # Dimension of node features
    hidden_channels=32,                       # Hidden layer size
    out_channels=len(labels.unique()),        # Number of output classes
    num_heads=4,                              # Number of attention heads
    num_layers=2                              # Number of Transformer layers
).to(device)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

# Weighted Loss Function for Class Imbalance
class_counts = torch.bincount(labels)
class_weights = 1.0 / class_counts.float()
class_weights = class_weights / class_weights.sum()
class_weights = class_weights.to(device)
criterion = torch.nn.CrossEntropyLoss(weight=class_weights)

# %%
# Train the Model
epochs = 100
loss_list, acc_list = [], []

for epoch in range(epochs):
    model.train()
    total_loss, correct, total = 0, 0, 0

    train_loader_tqdm = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}", leave=False)
    for batch in train_loader_tqdm:
        # Move data to the device (GPU/CPU)
        batch = batch.to(device)
        
        # Zero gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
       
        # Compute loss
        loss = criterion(outputs, batch.y)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        # Accumulate total loss
        total_loss += loss.item()

        # Compute Accuracy
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Update tqdm progress bar with current loss
        train_loader_tqdm.set_postfix(loss=loss.item())

    # Compute average loss and accuracy for the epoch
    avg_loss = total_loss / len(train_loader)
    train_accuracy = correct / total

    # Store loss and accuracy for plotting
    loss_list.append(avg_loss)
    acc_list.append(train_accuracy)

    # Print training progress
    print(f"Epoch {epoch+1}/{epochs}, Avg Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}")

# Save Training Loss and Accuracy
print("Training complete.")
# Out:
# Epoch 1/100, Avg Loss: 1.4000, Train Accuracy: 0.2585
# Epoch 2/100, Avg Loss: 0.5655, Train Accuracy: 0.2844
# Epoch 3/100, Avg Loss: 0.4766, Train Accuracy: 0.8225
# Epoch 4/100, Avg Loss: 0.3740, Train Accuracy: 0.9612
# Epoch 5/100, Avg Loss: 0.2751, Train Accuracy: 0.9814
# Epoch 6/100, Avg Loss: 0.1929, Train Accuracy: 0.9870
# Epoch 7/100, Avg Loss: 0.1423, Train Accuracy: 0.9951
# Epoch 8/100, Avg Loss: 0.0953, Train Accuracy: 0.9959
# Epoch 9/100, Avg Loss: 0.0733, Train Accuracy: 0.9961
# Epoch 10/100, Avg Loss: 0.0596, Train Accuracy: 0.9962
# Epoch 11/100, Avg Loss: 0.0510, Train Accuracy: 0.9963
# Epoch 12/100, Avg Loss: 0.0452, Train Accuracy: 0.9963
# Epoch 13/100, Avg Loss: 0.0409, Train Accuracy: 0.9963
# Epoch 14/100, Avg Loss: 0.0400, Train Accuracy: 0.9963
# Epoch 15/100, Avg Loss: 0.0308, Train Accuracy: 0.9964
# Epoch 16/100, Avg Loss: 0.0242, Train Accuracy: 0.9965
# Epoch 17/100, Avg Loss: 0.0186, Train Accuracy: 0.9964
# Epoch 18/100, Avg Loss: 0.1954, Train Accuracy: 0.9154
# Epoch 19/100, Avg Loss: 0.0204, Train Accuracy: 0.9965
# Epoch 20/100, Avg Loss: 0.0283, Train Accuracy: 0.9964
# Epoch 21/100, Avg Loss: 0.0357, Train Accuracy: 0.9963
# Epoch 22/100, Avg Loss: 0.0421, Train Accuracy: 0.9963
# Epoch 23/100, Avg Loss: 0.0477, Train Accuracy: 0.9962
# Epoch 24/100, Avg Loss: 0.0524, Train Accuracy: 0.9962
# Epoch 25/100, Avg Loss: 0.0565, Train Accuracy: 0.9961
# Epoch 26/100, Avg Loss: 0.0597, Train Accuracy: 0.9961
# Epoch 27/100, Avg Loss: 0.0624, Train Accuracy: 0.9961
# Epoch 28/100, Avg Loss: 0.0646, Train Accuracy: 0.9960
# Epoch 29/100, Avg Loss: 0.0662, Train Accuracy: 0.9960
# Epoch 30/100, Avg Loss: 0.0675, Train Accuracy: 0.9960
# Epoch 31/100, Avg Loss: 0.0683, Train Accuracy: 0.9961
# Epoch 32/100, Avg Loss: 0.0687, Train Accuracy: 0.9961
# Epoch 33/100, Avg Loss: 0.0687, Train Accuracy: 0.9961
# Epoch 34/100, Avg Loss: 0.0685, Train Accuracy: 0.9961
# Epoch 35/100, Avg Loss: 0.0678, Train Accuracy: 0.9962
# Epoch 36/100, Avg Loss: 0.0668, Train Accuracy: 0.9962
# Epoch 37/100, Avg Loss: 0.0658, Train Accuracy: 0.9962
# Epoch 38/100, Avg Loss: 0.0646, Train Accuracy: 0.9966
# Epoch 39/100, Avg Loss: 0.0636, Train Accuracy: 0.9968
# Epoch 40/100, Avg Loss: 0.0625, Train Accuracy: 0.9971
# Epoch 41/100, Avg Loss: 0.0614, Train Accuracy: 0.9972
# Epoch 42/100, Avg Loss: 0.0602, Train Accuracy: 0.9972
# Epoch 43/100, Avg Loss: 0.0589, Train Accuracy: 0.9972
# Epoch 44/100, Avg Loss: 0.0575, Train Accuracy: 0.9973
# Epoch 45/100, Avg Loss: 0.0561, Train Accuracy: 0.9973
# Epoch 46/100, Avg Loss: 0.0547, Train Accuracy: 0.9973
# Epoch 47/100, Avg Loss: 0.0532, Train Accuracy: 0.9973
# Epoch 48/100, Avg Loss: 0.0516, Train Accuracy: 0.9973
# Epoch 49/100, Avg Loss: 0.0498, Train Accuracy: 0.9974
# Epoch 50/100, Avg Loss: 0.0479, Train Accuracy: 0.9974
# Epoch 51/100, Avg Loss: 0.0459, Train Accuracy: 0.9974
# Epoch 52/100, Avg Loss: 0.0438, Train Accuracy: 0.9974
# Epoch 53/100, Avg Loss: 0.0415, Train Accuracy: 0.9974
# Epoch 54/100, Avg Loss: 0.0390, Train Accuracy: 0.9974
# Epoch 55/100, Avg Loss: 0.0365, Train Accuracy: 0.9974
# Epoch 56/100, Avg Loss: 0.0339, Train Accuracy: 0.9974
# Epoch 57/100, Avg Loss: 0.0311, Train Accuracy: 0.9974
# Epoch 58/100, Avg Loss: 0.0283, Train Accuracy: 0.9975
# Epoch 59/100, Avg Loss: 0.0255, Train Accuracy: 0.9976
# Epoch 60/100, Avg Loss: 0.0226, Train Accuracy: 0.9976
# Epoch 61/100, Avg Loss: 0.0196, Train Accuracy: 0.9976
# Epoch 62/100, Avg Loss: 0.0164, Train Accuracy: 0.9976
# Epoch 63/100, Avg Loss: 0.0130, Train Accuracy: 0.9976
# Epoch 64/100, Avg Loss: 0.0100, Train Accuracy: 0.9978
# Epoch 65/100, Avg Loss: 0.0107, Train Accuracy: 0.9983
# Epoch 66/100, Avg Loss: 0.0140, Train Accuracy: 0.9986
# Epoch 67/100, Avg Loss: 0.0084, Train Accuracy: 0.9978
# Epoch 68/100, Avg Loss: 0.0094, Train Accuracy: 0.9978
# Epoch 69/100, Avg Loss: 0.0104, Train Accuracy: 0.9978
# Epoch 70/100, Avg Loss: 0.0112, Train Accuracy: 0.9977
# Epoch 71/100, Avg Loss: 0.0118, Train Accuracy: 0.9977
# Epoch 72/100, Avg Loss: 0.0121, Train Accuracy: 0.9977
# Epoch 73/100, Avg Loss: 0.0123, Train Accuracy: 0.9977
# Epoch 74/100, Avg Loss: 0.0122, Train Accuracy: 0.9977
# Epoch 75/100, Avg Loss: 0.0121, Train Accuracy: 0.9977
# Epoch 76/100, Avg Loss: 0.0117, Train Accuracy: 0.9978
# Epoch 77/100, Avg Loss: 0.0113, Train Accuracy: 0.9978
# Epoch 78/100, Avg Loss: 0.0108, Train Accuracy: 0.9978
# Epoch 79/100, Avg Loss: 0.0101, Train Accuracy: 0.9978
# Epoch 80/100, Avg Loss: 0.0094, Train Accuracy: 0.9978
# Epoch 81/100, Avg Loss: 0.0086, Train Accuracy: 0.9978
# Epoch 82/100, Avg Loss: 0.0078, Train Accuracy: 0.9978
# Epoch 83/100, Avg Loss: 0.0076, Train Accuracy: 0.9978
# Epoch 84/100, Avg Loss: 0.0091, Train Accuracy: 0.9984
# Epoch 85/100, Avg Loss: 0.0086, Train Accuracy: 0.9984
# Epoch 86/100, Avg Loss: 0.0074, Train Accuracy: 0.9978
# Epoch 87/100, Avg Loss: 0.0075, Train Accuracy: 0.9978
# Epoch 88/100, Avg Loss: 0.0078, Train Accuracy: 0.9978
# Epoch 89/100, Avg Loss: 0.0081, Train Accuracy: 0.9978
# Epoch 90/100, Avg Loss: 0.0082, Train Accuracy: 0.9978
# Epoch 91/100, Avg Loss: 0.0081, Train Accuracy: 0.9978
# Epoch 92/100, Avg Loss: 0.0079, Train Accuracy: 0.9978
# Epoch 93/100, Avg Loss: 0.0076, Train Accuracy: 0.9978
# Epoch 94/100, Avg Loss: 0.0073, Train Accuracy: 0.9978
# Epoch 95/100, Avg Loss: 0.0071, Train Accuracy: 0.9978
# Epoch 96/100, Avg Loss: 0.0071, Train Accuracy: 0.9979
# Epoch 97/100, Avg Loss: 0.0074, Train Accuracy: 0.9983
# Epoch 98/100, Avg Loss: 0.0073, Train Accuracy: 0.9983
# Epoch 99/100, Avg Loss: 0.0070, Train Accuracy: 0.9979
# Epoch 100/100, Avg Loss: 0.0069, Train Accuracy: 0.9978
# Training complete.

# %%
import matplotlib.pyplot as plt
# Plot loss and accuracy for both training and validation
plt.figure(figsize=(14, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(range(epochs), loss_list, label="Train Loss", color="red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss over Epochs")
plt.grid(True)
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(range(epochs), acc_list, label="Train Accuracy", color="blue")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epochs")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
gt_loss_list = loss_list.copy()
gt_acc_list = acc_list.copy()

# %%
from sklearn.metrics import classification_report

model.eval()
correct, total = 0, 0
all_predictions = []
all_targets = []

with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device)
        outputs = model(batch.x, batch.edge_index, batch.edge_attr)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == batch.y).sum().item()
        total += batch.y.size(0)

        # Store for classification report
        all_predictions.extend(predicted.cpu().numpy())
        all_targets.extend(batch.y.cpu().numpy())
target_names = ["Benign", "Recon", "DoS"]
test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy:.4f}")

# Print Classification Report
print("\nClassification Report:")
print(classification_report(all_targets, all_predictions,  target_names= target_names, digits=4))
# Out:
# Test Accuracy: 0.9981
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign     0.1905    0.4444    0.2667        18
#        Recon     0.9986    0.9984    0.9985    344913
#          DoS     0.9974    0.9975    0.9975    204009
#
#     accuracy                         0.9981    548940
#    macro avg     0.7288    0.8135    0.7542    548940
# weighted avg     0.9981    0.9981    0.9981    548940

# %% [markdown]
# # Model Train Loss, Acc

# %%
import matplotlib.pyplot as plt

# Assuming gt_loss_list and gt_acc_list are defined and have the same length as other lists
# Define the number of epochs (ensure all lists are of the same length)
epochs_range = range(len(mpnn_acc_list))

plt.figure(figsize=(14, 6))

# 🔹 Loss Plot (With Markers)
plt.subplot(1, 2, 1)
plt.plot(epochs_range, sage_loss_list, label="SAGE", linestyle="--", marker="s", markersize=4)
plt.plot(epochs_range, gat_loss_list, label="GAT", linestyle="--", marker="d", markersize=4)
plt.plot(epochs_range, gcn_loss_list, label="GCN", linestyle="--", marker="^", markersize=4)
plt.plot(epochs_range, mpnn_loss_list, label="MPNN", linestyle="--", marker="o", markersize=4)
plt.plot(epochs_range, gt_loss_list, label="GraphTransformer", linestyle="--", marker="*", markersize=4)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.title("Comparison of Training Loss Across GNN Architectures", fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

# 🔹 Accuracy Plot (Without Markers)
plt.subplot(1, 2, 2)
plt.plot(epochs_range, sage_acc_list, label="SAGE", linestyle="-", linewidth=1.5)
plt.plot(epochs_range, gat_acc_list, label="GAT", linestyle="-", linewidth=1.5)
plt.plot(epochs_range, gcn_acc_list, label="GCN", linestyle="-", linewidth=1.5)
plt.plot(epochs_range, mpnn_acc_list, label="MPNN", linestyle="-", linewidth=1.5)
plt.plot(epochs_range, gt_acc_list, label="GraphTransformer", linestyle="-", linewidth=1.5)
plt.xlabel("Epochs", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.title("Comparison of Training Accuracy Across GNN Architectures", fontsize=14)
plt.legend(fontsize=10)
plt.grid(True)

# Adjust layout for a professional appearance
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Performance Visualization

# %%
import pandas as pd

# Define the dataset as a dictionary
result = {
    "Dataset": ["Network Traffic"] * 5,  # Repeated for all models
    "Model": ["SAGE", "GAT", "GCN", "MPNN", "GraphTransformer"],
    "Precision": [0.9971, 0.9910, 0.9860, 0.9979, 0.9981],
    "Recall": [0.9967, 0.9908, 0.9856, 0.9975, 0.9981],
    "F1-Score": [0.9969, 0.9908, 0.9857, 0.9977, 0.9981],
    "Accuracy": [0.9967, 0.9908, 0.9856, 0.9975, 0.9981]
}

# Create the DataFrame
df = pd.DataFrame(result)

# Display the DataFrame
print(df)
# Out:
#            Dataset             Model  Precision  Recall  F1-Score  Accuracy
# 0  Network Traffic              SAGE     0.9971  0.9967    0.9969    0.9967
# 1  Network Traffic               GAT     0.9910  0.9908    0.9908    0.9908
# 2  Network Traffic               GCN     0.9860  0.9856    0.9857    0.9856
# 3  Network Traffic              MPNN     0.9979  0.9975    0.9977    0.9975
# 4  Network Traffic  GraphTransformer     0.9981  0.9981    0.9981    0.9981

# %%
from matplotlib.cm import get_cmap

# Generate a color palette using a colormap (e.g., 'tab10')
colormap = get_cmap('tab10')
colors = {
    "SAGE": colormap(0),       # Blue
    "GAT": colormap(1),        # Orange
    "GCN": colormap(2),        # Green
    "MPNN": colormap(3),       # Red
    "GraphTransformer": colormap(4)  # Purple
}

# Metrics for plotting
metrics = ["Precision", "Recall", "F1-Score", "Accuracy"]
x = np.arange(len(metrics))  # X positions for metrics
bar_width = 0.15  # Width of the bars

# Create a figure
plt.figure(figsize=(12, 6))

# Plot bars for each model
for i, model in enumerate(df["Model"]):
    plt.bar(
        x + i * bar_width,  # Shift bars for each model
        df.loc[i, metrics],  # Model's metrics
        bar_width,  # Width of the bar
        label=model,  # Legend label
        color=colors[model],  # Color for the model
    )

# Configure the plot
plt.xticks(x + bar_width * (len(df["Model"]) - 1) / 2, metrics, fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.title("Performance Metrics Across GNN Models", fontsize=14)
plt.ylim(0.98, 1.0)  # Focus on high scores for better visibility
plt.legend(fontsize=10)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Adjust layout for clarity
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_2159933/2222733584.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = get_cmap('tab10')

# %%
# Visualization - Bar Chart for Metrics
metrics = ["Precision", "Recall", "F1-Score", "Accuracy"]
x = np.arange(len(df["Model"]))  # X positions for the groups
width = 0.2  # Width of the bars

# Create a figure
plt.figure(figsize=(12, 6))

# Plot each metric
for i, metric in enumerate(metrics):
    plt.bar(x + i * width, df[metric], width, label=metric)

# Configure the plot
plt.xticks(x + width * (len(metrics) - 1) / 2, df["Model"], fontsize=10, rotation=45)
plt.ylabel("Score", fontsize=12)
plt.title("Performance Metrics Across GNN Models", fontsize=14)
plt.ylim(0.98, 1.0)  # Focus on the range close to 1 for better visibility
plt.legend(fontsize=10)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import torch
import gc

# Free up GPU memory
gc.collect()
torch.cuda.empty_cache()
